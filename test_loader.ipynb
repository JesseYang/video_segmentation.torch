-- %%
require 'Loader'
-- Out:
-- true

-- %%
indexer = indexer('./prepare_datasets/lmdb/train/', 10)

-- %%
loader = Loader('./prepare_datasets/lmdb/train/')

-- %%
inds = indexer:nextIndices()

-- %%
inds
-- Out:
--  161
--  162
--  163
--  164
--  165
--  166
--  167
--  168
--  169
--  170
-- [torch.FloatTensor of size 10]

-- %%
data, targets = loader:nextBatch(inds)

-- %%
torch.type(data)
-- Out:
-- torch.FloatTensor

-- %%
require 'image'
i = 1
print(targets[i])
itorch.image({data[i][1], data[i][2], data[i][3], data[i][4], data[i][5], data[i][6], data[i][7], data[i][8], data[i][9], data[i][10], data[i][11]})
-- Out:
-- 1
-- Console does not support images

-- %%
targets
-- Out:
--  1
--  1
--  1
--  1
--  2
--  2
--  2
--  2
--  2
--  2
-- [torch.FloatTensor of size 10]

-- %%
a = torch.Tensor(3,4)

-- %%
a
-- Out:
--  3.7731e-13  4.5701e-41  3.7731e-13  4.5701e-41
--  0.0000e+00  0.0000e+00  0.0000e+00  0.0000e+00
--  7.7135e+31  2.0558e+32  1.8755e+28  3.1093e-18
-- [torch.FloatTensor of size 3x4]

-- %%
a - 1
-- Out:
-- -1.0000e+00 -1.0000e+00 -1.0000e+00 -1.0000e+00
-- -1.0000e+00 -1.0000e+00 -1.0000e+00 -1.0000e+00
--  7.7135e+31  2.0558e+32  1.8755e+28 -1.0000e+00
-- [torch.FloatTensor of size 3x4]

-- %%
a:mean()
-- Out:
-- 2.3561004877407e+31

-- %%
a = torch:ByteTensor(3, 4)

-- %%
a
-- Out:
-- [torch.ByteTensor with no dimension]
